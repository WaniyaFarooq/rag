# %% [markdown]
# ### data ingestion ###

# %%
from langchain_core.documents import Document

# %%
doc = Document(
    page_content = "this is the main text content I  am using to create rag"
   , metadata={
        "source":"example.txt",
        "page":1,
        "author":"waniya farooq",
        "date_created":'2026-56-24'
    }
)

# %%
doc
# Out:
# Document(metadata={'source': 'example.txt', 'page': 1, 'author': 'waniya farooq', 'date_created': '2026-56-24'}, page_content='this is the main text content I  am using to create rag')

# %%
import os 
os.makedirs("../data/text_files",exist_ok=True)

# %%
# sample_text = {
#     "../data/text_files/p.txt":"popdkfodf"
# }
# for file,content in sample_text.items():
#     with open(file,"w") as f:
#         f.write(content)

# %%
sample_texts={
    "../data/text_files/python_intro.txt":"""Python Programming Introduction

Python is a high-level, interpreted programming language known for its simplicity and readability.
Created by Guido van Rossum and first released in 1991, Python has become one of the most popular
programming languages in the world.

Key Features:
- Easy to learn and use
- Extensive standard library
- Cross-platform compatibility
- Strong community support

Python is widely used in web development, data science, artificial intelligence, and automation.""",
    
    "../data/text_files/machine_learning.txt": """Machine Learning Basics

Machine learning is a subset of artificial intelligence that enables systems to learn and improve
from experience without being explicitly programmed. It focuses on developing computer programs
that can access data and use it to learn for themselves.

Types of Machine Learning:
1. Supervised Learning: Learning with labeled data
2. Unsupervised Learning: Finding patterns in unlabeled data
3. Reinforcement Learning: Learning through rewards and penalties

Applications include image recognition, speech processing, and recommendation systems
    
    
    """

}

for filepath,content in sample_texts.items():
    with open(filepath,'w',encoding="utf-8") as f:
        f.write(content)

print("✅ Sample text files created!")
# Out:
# ✅ Sample text files created!

# %%
from langchain_community.document_loaders import TextLoader
# Out:
# C:\Users\waniy\AppData\Local\Temp\ipykernel_21896\2929458509.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import TextLoader

# %%
loader = TextLoader("../data/text_files/python_intro.txt",encoding="utf-8")
document = loader.load()
print(document)
# Out:
# [Document(metadata={'source': '../data/text_files/python_intro.txt'}, page_content='Python Programming Introduction\n\nPython is a high-level, interpreted programming language known for its simplicity and readability.\nCreated by Guido van Rossum and first released in 1991, Python has become one of the most popular\nprogramming languages in the world.\n\nKey Features:\n- Easy to learn and use\n- Extensive standard library\n- Cross-platform compatibility\n- Strong community support\n\nPython is widely used in web development, data science, artificial intelligence, and automation.')]

# %% [markdown]
# # directory loader

# %%
from langchain_community.document_loaders import DirectoryLoader

## load all the text files from the directory 
dir_loader = DirectoryLoader(
    "../data/text_files",
    glob="**/*.txt",
    loader_cls=TextLoader,
    loader_kwargs={'encoding':'utf-8'},
    show_progress=True
)

# %%
documents = dir_loader.load()
print(documents)
# Out:
# 100%|██████████| 2/2 [00:00<00:00, 56.22it/s]
# [Document(metadata={'source': '..\\data\\text_files\\machine_learning.txt'}, page_content='Machine Learning Basics\n\nMachine learning is a subset of artificial intelligence that enables systems to learn and improve\nfrom experience without being explicitly programmed. It focuses on developing computer programs\nthat can access data and use it to learn for themselves.\n\nTypes of Machine Learning:\n1. Supervised Learning: Learning with labeled data\n2. Unsupervised Learning: Finding patterns in unlabeled data\n3. Reinforcement Learning: Learning through rewards and penalties\n\nApplications include image recognition, speech processing, and recommendation systems\n\n\n    '), Document(metadata={'source': '..\\data\\text_files\\python_intro.txt'}, page_content='Python Programming Introduction\n\nPython is a high-level, interpreted programming language known for its simplicity and readability.\nCreated by Guido van Rossum and first released in 1991, Python has become one of the most popular\nprogramming languages in the world.\n\nKey Features:\n- Easy to learn and use\n- Extensive standard library\n- Cross-platform compatibility\n- Strong community support\n\nPython is widely used in web development, data science, artificial intelligence, and automation.')]

# %%
from langchain_community.document_loaders import DirectoryLoader,PyPDFLoader

## load all the text files from the directory 
dir_loader = DirectoryLoader(
    "../data/pdf_files",
    glob="**/*.pdf",
    loader_cls=PyPDFLoader,
    show_progress=True
    
)
documents = dir_loader.load()
documents
# Out:
# 100%|██████████| 1/1 [00:00<00:00,  3.68it/s]
# [Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2026-06-23T12:55:00+05:00', 'author': 'Un-named', 'moddate': '2026-06-23T12:55:00+05:00', 'source': '..\\data\\pdf_files\\Waniya_Farooq_Resume .pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content="WANIYA FAROOQ \nAI & Data Engineering Student \n+92 323 4062926  |  waniyafarooq18@gmail.com  |  linkedin.com/in/waniya-farooq  |  github.com/WaniyaFarooq  |  Lahore, Pakistan \nPROFESSIONAL SUMMARY \nAI undergraduate at COMSATS University Lahore (CGPA: 3.73/4.00) with hands-on experience building AI-powered applications and data \npipelines. Proficient in SQL, ETL processes, database design, and end-to-end ML/LLM integration. Experienced with cloud platforms (Azure \nfundamentals) and data warehousing concepts. Certified through Harvard CS50 and Coursera IBM. Strong foundation in DSA with extensive \nLeetCode practice. \nEDUCATION \nBS Artificial Intelligence | COMSATS University Islamabad, Lahore Campus    2024 – Present   \nCGPA: 3.73 / 4.00   \nRelevant Coursework: OOP, Data Structures & Algorithms, Database Systems, Machine Learning, Linear Algebra, Statistics \nTECHNICAL SKILLS \nLanguages: Python, SQL, C++, Java, JavaScript, HTML/CSS \nData Engineering & ETL: ETL Pipeline Design, Data Wrangling, Data Warehousing Concepts, SQL Querying, Null-value Imputation, \nData Validation, CSV/JSON Processing \nDatabases: SQLite, MySQL, SQLAlchemy ORM, Relational Schema Design (9-table normalized DB), CRUD Operations \nCloud & Platforms: Microsoft Azure (Fundamentals), Git, GitHub, VS Code, Jupyter Notebook \nML / Data Libraries: scikit-learn, Pandas, NumPy, Matplotlib, Seaborn \nWeb Frameworks: Flask, Django, SQLAlchemy, WTForms, Jinja2, Streamlit \nPROJECTS \nNetflix Dataset —ETL & Exploratory Data Analysis   \nPython | Pandas | NumPy | Seaborn | Matplotlib | Jupyter Notebook \n• Designed and executed an end-to-end ETL pipeline on 100+ Netflix records: extracted raw data, performed data wrangling and null-\nvalue imputation across 5 critical features, and loaded clean data for analysis. \n• Engineered 6 statistical visualizations (histogram, pie, scatter, bar, multi-subplot) uncovering content distribution patterns, rating \nsegmentation, release-year trends, and geo-based content density across 10 top-producing countries. \n• Applied data warehouse-style schema thinking to organize and query tabular data, enabling structured reporting on content metadata. \nAI Smart Attendance System — Face Recognition-Based Automation   \nPython | OpenCV | LBPH | Streamlit | Pandas | Matplotlib \n• Built end-to-end face recognition pipeline using OpenCV Haar Cascade + LBPH algorithm for real-time student detection and automatic \nattendance marking with <70ms processing latency. \n• Architected modular system with 5 core classes (StudentManager, AttendanceManager, FileHandler, FaceRecognizer) demonstrating \nclean OOP design, separation of concerns, and production-grade error handling. \n• Implemented multi-layer duplicate prevention via session tracking, CSV validation, and cooldown mechanisms — ensuring data \nintegrity across concurrent webcam streams (ETL-style data quality controls). \n• Developed interactive Streamlit dashboard with 7 pages, real-time PDF export, Pandas analytics, and Matplotlib visualizations \nsupporting 50+ student datasets with heatmaps and attendance trend analysis. \nHotel Reservation System — Full-Stack Web Application   \nPython | Flask | SQLAlchemy | SQLite | WTForms | Jinja2 \n• Built a full-stack application with 2 role-based portals (Admin & Customer) using Flask Blueprint architecture for separation of \nconcerns. \n• Designed a 9-table normalized relational database in SQLite with SQLAlchemy ORM handling 100% of CRUD operations — \ndemonstrating strong database schema design and SQL proficiency. \n• Applied ETL principles to automate staff onboarding: extracted form in ...

# %%
type(documents)
# Out:
# list
